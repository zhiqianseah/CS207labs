# %% [markdown]
# ## Q1.
#
# Add methods `__iter__` to your project Time Series class to iterate over values, a method `itertimes` to iterate over times, a method `itervalues` to iterate over values, and a method `iteritems` to iterate over time-value pairs. (This is a similar interface to python dictionaries). To test these, check both the types of the results and the answers you expect.

# %%
#your code here
See project repo

# %% [markdown]
# ## Q2.
#
# An online mean and standard deviation algorithm.
#
# Below is a function to generate a potentially infinite stream of 1-D data.

# %%
from random import normalvariate, random
from itertools import count
def make_data(m, stop=None):
    for _ in count():
        if stop and _ > stop:
            break
        yield 1.0e09 + normalvariate(0, m*random() )

# %% [markdown]
# Here is an implementation of an online mean algorithm..see http://www.johndcook.com/blog/standard_deviation/ and the link to http://www.johndcook.com/blog/2008/09/26/comparing-three-methods-of-computing-standard-deviation/ in-between. (Convince yourselves of the formulas...)

# %%
def online_mean(iterator):
    n = 0
    mu = 0
    for value in iterator:
        n += 1
        delta = value - mu
        mu = mu + delta/n
        yield mu

# %% [markdown]
# We use out generator functions to implement iterators:

# %%
g = make_data(5, 10)
list(g)
# Out:
# [999999998.8326192,
#  999999994.8669225,
#  1000000001.381039,
#  1000000000.8228903,
#  1000000000.1035341,
#  1000000004.1913975,
#  1000000000.0465633,
#  1000000001.3668858,
#  999999999.833798,
#  1000000005.4417261,
#  1000000006.451432]

# %%
g = online_mean(make_data(5, 100))
print(type(g))
list(g)
# Out:
# <class 'generator'>
# [999999999.3036265,
#  999999999.5794395,
#  1000000004.1289467,
#  1000000002.9335691,
#  1000000003.2530761,
#  1000000003.1746886,
#  1000000003.0089784,
#  1000000002.5550864,
#  1000000002.2710607,
#  1000000002.0764154,
#  1000000001.9780772,
#  1000000001.7327658,
#  1000000001.6950427,
#  1000000001.7154272,
#  1000000001.5607852,
#  1000000001.2581749,
#  1000000001.2039933,
#  1000000001.0333866,
#  1000000000.7398635,
#  1000000000.48475,
#  1000000000.5923496,
#  1000000000.5680795,
#  1000000000.5188496,
#  1000000000.7515411,
#  1000000000.6729517,
#  1000000000.5897677,
#  1000000000.6055403,
#  1000000000.5865349,
#  1000000000.8006344,
#  1000000000.7521873,
#  1000000000.5912223,
#  1000000000.5201908,
#  1000000000.5113152,
#  1000000000.5605108,
#  1000000000.535201,
#  1000000000.5668525,
#  1000000000.4498888,
#  1000000000.2258179,
#  1000000000.2808614,
#  1000000000.4903799,
#  1000000000.5384964,
#  1000000000.5219718,
# ...

# %% [markdown]
# ### 2.1
#
# Implement the standard deviation algorithm as a generator function as
#
# ```python
# def online_mean_dev(iterator):
#     BLA BLA
#     if n > 1:
#         stddev = math.sqrt(dev_accum/(n-1))
#         yield (n, value, mu, stddev)
# ```

# %%
# your code here
import math
def online_mean_dev(iterator):
    n = 0
    dev_accum = 0
    mu = 0
    for value in iterator:
        n+=1
        if n > 1:
            mu_temp = mu + (value - mu)/n
            dev_accum = dev_accum + (value-mu)*(value - mu_temp)
            mu = mu_temp
            #yield n
            stddev = math.sqrt(dev_accum/(n-1))
            yield (n, value, mu, stddev)
        else:
            mu = value;

# %% [markdown]
# Here we make 100000 element data, and run this iterator on it (imagine running this on a time-series being slowly read from disk

# %%
data_with_stats = online_mean_dev(make_data(5, 100000))
print (type(data_with_stats))
list(data_with_stats)
# Out:
# <class 'generator'>
# [(2, 1000000000.1723119, 1000000002.6221143, 3.464543777349716),
#  (3, 1000000000.719875, 1000000001.9880345, 2.684716602366042),
#  (4, 999999997.0619688, 1000000000.7565181, 3.2972210067102905),
#  (5, 999999999.2422134, 1000000000.4536572, 2.9346845734727496),
#  (6, 999999998.030665, 1000000000.0498252, 2.80506339676991),
#  (7, 1000000004.661692, 1000000000.7086633, 3.097653551447079),
#  (8, 999999997.5256541, 1000000000.3107872, 3.0807663631438866),
#  (9, 999999998.3563895, 1000000000.0936319, 2.9545116366342694),
#  (10, 999999998.9544551, 999999999.9797142, 2.808737622724489),
#  (11, 1000000003.934614, 1000000000.3392504, 2.9192527405895192),
#  (12, 1000000004.9338081, 1000000000.7221303, 3.083256277683067),
#  (13, 999999999.4998469, 1000000000.6281085, 2.97139441668962),
#  (14, 1000000002.0133805, 1000000000.7270565, 2.8787300357247187),
#  (15, 999999998.3955214, 1000000000.5716208, 2.838583376836042),
# ...

# %% [markdown]
# ## Q3.
#
# Let's do Anomaly detection. Write a routine `is_ok`:
#
# ```python
# def is_ok(level, t)
# ```
#
# which takes a tuple like the one yielded by your code above and returns True if the value is inbetween `level`-$\sigma$ of the mean.

# %%
#your code here
def is_ok(level,t):
    value = t[1]
    mean = t[2]
    if (level - mean < value) and (value < level + mean):
        return True
    else:
        return False

# %% [markdown]
# We use this function to create a predicate passed through to `itertools.filterfalse` which is then used to obtain an iterator on the anomalies.

# %%
from itertools import filterfalse
pred = lambda t: is_ok(5, t)

#get a generator for the data
data_with_stats = online_mean_dev(make_data(5, 100000))

anomalies = filterfalse(pred, list(data_with_stats))

# %% [markdown]
# We materialize the anomalies...

# %%
list(anomalies)#materialize
# Out:
# [(20, 1000000009.716922, 1000000000.2452734, 2.807266201763873),
#  (29, 1000000005.9635415, 999999999.8406495, 3.442075864226475),
#  (44, 1000000005.0371329, 999999999.5487316, 3.298848458625735),
#  (53, 1000000007.3504218, 999999999.7096088, 3.3165367218882715),
#  (81, 1000000010.1932219, 999999999.6653976, 3.4917194427050045),
#  (121, 1000000006.3587912, 999999999.6906639, 3.1128971648587465),
#  (144, 1000000005.4180868, 999999999.6671219, 2.9659349091266596),
#  (151, 1000000007.2216433, 999999999.6906638, 2.982503843663481),
#  (155, 1000000005.5401602, 999999999.7355013, 3.0016377661807017),
#  (191, 1000000009.3055091, 999999999.7234097, 2.962348211275306),
#  (201, 1000000004.9028567, 999999999.7990062, 2.934103496811574),
#  (202, 1000000005.6722525, 999999999.8280817, 2.955824775378189),
#  (210, 1000000006.0092261, 999999999.797565, 3.0017181419044188),
#  (218, 1000000006.0603566, 999999999.8058445, 2.988537364072049),
# ...

# %% [markdown]
# ## To think of, but not hand in
#
# What kinds of anomalies will this algorithm pick up? What kinds would a shorter "window" of anomaly detection, like 100 points around the time in question pick? How might you create an algorithm which does window based averaging? (hint: the window size is small compared to the time series size).
#
# Finally think a bit of how you might implement all of this in a production environment..remember that data streaming in might get backed up when you handle an anomaly.
#
# (Some inspiration might accrue if you look at the docs for `collections.deque`).

# %% [markdown]
# This algorithm will pick up outliers in a dataset.
#
# Do window-based averaging by processing points in batches
#
# Depends on what "handling an anomaly" means. If it is just removing from the dataset, that is generally a very quick operation. If some longer task has to be done for an anomaly, a separate thread can be spawned to handle it
